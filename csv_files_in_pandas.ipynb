# %% [markdown]
# <a href="https://colab.research.google.com/github/sukanyaganik14-collab/practice/blob/main/csv_files_in_pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
help(pd.read_csv)
# Out:
# Help on function read_csv in module pandas.io.parsers.readers:
#
# ...

# %%
from google.colab import drive; drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv('/content/drive/MyDrive/pima.csv')

# %%
import os

# %% [markdown]
# to print cwd means current working directory

# %%
print(os.getcwd())
# Out:
# /content

# %% [markdown]
# how to write csv files in pandas

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# to print all the column names

# %%
df.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %% [markdown]
# to read a complete row

# %%
df = pd.read_csv('/content/drive/MyDrive/pima.csv', nrows = 4)
df
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0

# %% [markdown]
# to read a column

# %%
df = pd.read_csv('/content/drive/MyDrive/pima.csv', usecols = range(4))
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness
# 0              6      148             72             35
# 1              1       85             66             29
# 2              8      183             64              0
# 3              1       89             66             23
# 4              0      137             40             35
# ..           ...      ...            ...            ...
# 763           10      101             76             48
# 764            2      122             70             27
# 765            5      121             72             23
# 766            1      126             60              0
# 767            1       93             70             31
#
# [768 rows x 4 columns]

# %% [markdown]
# to read both column and a row

# %%
df = pd.read_csv('/content/drive/MyDrive/pima.csv', usecols = range(2), nrows = 4)
df
# Out:
#    Pregnancies  Glucose
# 0            6      148
# 1            1       85
# 2            8      183
# 3            1       89

# %%
df = pd.read_csv('/content/drive/MyDrive/pima.csv', skiprows = 4)
df
# Out:
#       1   89  66  23   94  28.1  0.167  21  0
# 0     0  137  40  35  168  43.1  2.288  33  1
# 1     5  116  74   0    0  25.6  0.201  30  0
# 2     3   78  50  32   88  31.0  0.248  26  1
# 3    10  115   0   0    0  35.3  0.134  29  0
# 4     2  197  70  45  543  30.5  0.158  53  1
# ..   ..  ...  ..  ..  ...   ...    ...  .. ..
# 759  10  101  76  48  180  32.9  0.171  63  0
# 760   2  122  70  27    0  36.8  0.340  27  0
# 761   5  121  72  23  112  26.2  0.245  30  0
# 762   1  126  60   0    0  30.1  0.349  47  1
# 763   1   93  70  31    0  30.4  0.315  23  0
#
# [764 rows x 9 columns]

# %%
df = pd.read_csv('/content/drive/MyDrive/pima.csv')
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
df = pd.read_csv('/content/drive/MyDrive/pima.csv', index_col = 'BMI' )
df
# Out:
#       Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin  \
# BMI
# 33.6            6      148             72             35        0
# 26.6            1       85             66             29        0
# 23.3            8      183             64              0        0
# 28.1            1       89             66             23       94
# 43.1            0      137             40             35      168
# ...           ...      ...            ...            ...      ...
# 32.9           10      101             76             48      180
# 36.8            2      122             70             27        0
# 26.2            5      121             72             23      112
# 30.1            1      126             60              0        0
# 30.4            1       93             70             31        0
#
#       DiabetesPedigreeFunction  Age  Outcome
# BMI
# 33.6                     0.627   50        1
# 26.6                     0.351   31        0
# ...

# %% [markdown]
# how to write csv file

# %%
pd.read_csv('/content/drive/MyDrive/pima.csv')
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
df=pd.read_csv('/content/drive/MyDrive/pima.csv')
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %% [markdown]
# head displays first 5 rows

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %% [markdown]
# to display only one row

# %%
df.head(1)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1

# %%
df.head(8)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
# 5            5      116             74              0        0  25.6
# 6            3       78             50             32       88  31.0
# 7           10      115              0              0        0  35.3
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1
# 5                     0.201   30        0
# 6                     0.248   26        1
# ...

# %% [markdown]
# tail displays 5 rows from the bottom

# %%
df.tail()
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0

# %%
df.tail(1)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 767                     0.315   23        0

# %%
df.tail(8)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 760            2       88             58             26       16  28.4
# 761            9      170             74             31        0  44.0
# 762            9       89             62              0        0  22.5
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 760                     0.766   22        0
# 761                     0.403   43        1
# 762                     0.142   33        0
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# ...

# %% [markdown]
# the datatype of the values can be changed

# %%
df = pd.read_csv('/content/drive/MyDrive/pima.csv', dtype = {'Age': 'float64'})
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction   Age  Outcome
# 0                       0.627  50.0        1
# ...

# %%
df = pd.read_csv('/content/drive/MyDrive/pima.csv', dtype = {'Glucose': 'float64'})
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6    148.0             72             35        0  33.6
# 1              1     85.0             66             29        0  26.6
# 2              8    183.0             64              0        0  23.3
# 3              1     89.0             66             23       94  28.1
# 4              0    137.0             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10    101.0             76             48      180  32.9
# 764            2    122.0             70             27        0  36.8
# 765            5    121.0             72             23      112  26.2
# 766            1    126.0             60              0        0  30.1
# 767            1     93.0             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...
